# %%
# ignore this cell, this is just a helper cell to provide the magic %highlight_file
# %run ../highlighter.py

# %% [markdown]
# # Get Facts

# %% [markdown]
# Following runbook will connect to devices in the site "cmh" and gather information about basic facts and interfaces.
#
# ## Code

# %%
# %highlight_file get_facts.py
# Out:
# <style>
# .pygments .hll { background-color: #ffffcc }
# .pygments  { background: #f8f8f8; }
# .pygments .c { color: #408080; font-style: italic } /* Comment */
# .pygments .err { border: 1px solid #FF0000 } /* Error */
# .pygments .k { color: #008000; font-weight: bold } /* Keyword */
# .pygments .o { color: #666666 } /* Operator */
# .pygments .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .pygments .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .pygments .cp { color: #BC7A00 } /* Comment.Preproc */
# .pygments .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .pygments .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .pygments .cs { color: #408080; font-style: italic } /* Comment.Special */
# .pygments .gd { color: #A00000 } /* Generic.Deleted */
# .pygments .ge { font-style: italic } /* Generic.Emph */
# .pygments .gr { color: #FF0000 } /* Generic.Error */
# .pygments .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .pygments .gi { color: #00A000 } /* Generic.Inserted */
# .pygments .go { color: #888888 } /* Generic.Output */
# .pygments .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .pygments .gs { font-weight: bold } /* Generic.Strong */
# .pygments .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .pygments .gt { color: #0044DD } /* Generic.Traceback */
# .pygments .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .pygments .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .pygments .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .pygments .kp { color: #008000 } /* Keyword.Pseudo */
# .pygments .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .pygments .kt { color: #B00040 } /* Keyword.Type */
# .pygments .m { color: #666666 } /* Literal.Number */
# .pygments .s { color: #BA2121 } /* Literal.String */
# .pygments .na { color: #7D9029 } /* Name.Attribute */
# .pygments .nb { color: #008000 } /* Name.Builtin */
# .pygments .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .pygments .no { color: #880000 } /* Name.Constant */
# .pygments .nd { color: #AA22FF } /* Name.Decorator */
# .pygments .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .pygments .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .pygments .nf { color: #0000FF } /* Name.Function */
# .pygments .nl { color: #A0A000 } /* Name.Label */
# .pygments .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .pygments .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .pygments .nv { color: #19177C } /* Name.Variable */
# .pygments .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .pygments .w { color: #bbbbbb } /* Text.Whitespace */
# .pygments .mb { color: #666666 } /* Literal.Number.Bin */
# .pygments .mf { color: #666666 } /* Literal.Number.Float */
# .pygments .mh { color: #666666 } /* Literal.Number.Hex */
# .pygments .mi { color: #666666 } /* Literal.Number.Integer */
# .pygments .mo { color: #666666 } /* Literal.Number.Oct */
# .pygments .sa { color: #BA2121 } /* Literal.String.Affix */
# .pygments .sb { color: #BA2121 } /* Literal.String.Backtick */
# .pygments .sc { color: #BA2121 } /* Literal.String.Char */
# .pygments .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .pygments .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .pygments .s2 { color: #BA2121 } /* Literal.String.Double */
# .pygments .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .pygments .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .pygments .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .pygments .sx { color: #008000 } /* Literal.String.Other */
# .pygments .sr { color: #BB6688 } /* Literal.String.Regex */
# .pygments .s1 { color: #BA2121 } /* Literal.String.Single */
# .pygments .ss { color: #19177C } /* Literal.String.Symbol */
# .pygments .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .pygments .fm { color: #0000FF } /* Name.Function.Magic */
# .pygments .vc { color: #19177C } /* Name.Variable.Class */
# .pygments .vg { color: #19177C } /* Name.Variable.Global */
# .pygments .vi { color: #19177C } /* Name.Variable.Instance */
# .pygments .vm { color: #19177C } /* Name.Variable.Magic */
# .pygments .il { color: #666666 } /* Literal.Number.Integer.Long */
# </style>
# <div class="pygments"><pre><span></span><span class="lineno"> 1 </span><span class="ch">#!/usr/bin/env python</span>
# <span class="lineno"> 2 </span><span class="sd">&quot;&quot;&quot;</span>
# <span class="lineno"> 3 </span><span class="sd">Very simple runbook to get facts and print them on the screen.</span>
# <span class="lineno"> 4 </span><span class="sd">&quot;&quot;&quot;</span>
# <span class="lineno"> 5 </span>
# <span class="lineno"> 6 </span><span class="kn">from</span> <span class="nn">brigade.easy</span> <span class="k">import</span> <span class="n">easy_brigade</span>
# <span class="lineno"> 7 </span><span class="kn">from</span> <span class="nn">brigade.plugins.functions.text</span> <span class="k">import</span> <span class="n">print_title</span>
# <span class="lineno"> 8 </span><span class="kn">from</span> <span class="nn">brigade.plugins.tasks</span> <span class="k">import</span> <span class="n">networking</span><span class="p">,</span> <span class="n">text</span>
# <span class="lineno"> 9 </span>
# <span class="lineno">10 </span>
# <span class="lineno">11 </span><span class="n">brg</span> <span class="o">=</span> <span class="n">easy_brigade</span><span class="p">(</span>
# <span class="lineno">12 </span>        <span class="n">host_file</span><span class="o">=</span><span class="s2">&quot;../inventory/hosts.yaml&quot;</span><span class="p">,</span>
# <span class="lineno">13 </span>        <span class="n">group_file</span><span class="o">=</span><span class="s2">&quot;../inventory/groups.yaml&quot;</span><span class="p">,</span>
# <span class="lineno">14 </span>        <span class="n">dry_run</span><span class="o">=</span><span class="kc">False</span><span class="p">,</span>
# <span class="lineno">15 </span>        <span class="n">raise_on_error</span><span class="o">=</span><span class="kc">False</span><span class="p">,</span>
# <span class="lineno">16 </span><span class="p">)</span>
# <span class="lineno">17 </span>
# <span class="lineno">18 </span><span class="n">print_title</span><span class="p">(</span><span class="s2">&quot;Getting interfaces and facts&quot;</span><span class="p">)</span>
# <span class="lineno">19 </span>
# <span class="lineno">20 </span><span class="c1"># select which devices we want to work with</span>
# <span class="lineno">21 </span><span class="n">filtered</span> <span class="o">=</span> <span class="n">brg</span><span class="o">.</span><span class="n">filter</span><span class="p">(</span><span class="nb">type</span><span class="o">=</span><span class="s2">&quot;network_device&quot;</span><span class="p">,</span> <span class="n">site</span><span class="o">=</span><span class="s2">&quot;cmh&quot;</span><span class="p">)</span>
# <span class="lineno">22 </span>
# <span class="lineno">23 </span><span class="c1"># we are going to gather &quot;interfaces&quot; and &quot;facts&quot;</span>
# <span class="lineno">24 </span><span class="c1"># information with napalm</span>
# <span class="lineno">25 </span><span class="n">results</span> <span class="o">=</span> <span class="n">filtered</span><span class="o">.</span><span class="n">run</span><span class="p">(</span><span class="n">networking</span><span class="o">.</span><span class="n">napalm_get</span><span class="p">,</span>
# <span class="lineno">26 </span>                       <span class="n">getters</span><span class="o">=</span><span class="p">[</span><span class="s2">&quot;interfaces&quot;</span><span class="p">,</span> <span class="s2">&quot;facts&quot;</span><span class="p">])</span>
# <span class="lineno">27 </span>
# <span class="lineno">28 </span><span class="c1"># Let&#39;s print the result on screen</span>
# <span class="lineno">29 </span><span class="n">filtered</span><s

# %% [markdown]
# ## Demo
#
# Let's run it:

# %%
# %run get_facts.py
# Out:
# **** Getting interfaces and facts **********************************************
# * spine00.cmh ** changed : False ***********************************************
# ---- napalm_get ** changed : False  --------------------------------------------
# { 'facts': { 'fqdn': 'spine00.cmh.cmh.acme.com',
#              'hostname': 'spine00.cmh',
#              'interface_list': ['Ethernet1', 'Ethernet2', 'Management1'],
#              'model': 'vEOS',
#              'os_version': '4.17.5M-4414219.4175M',
#              'serial_number': '',
#              'uptime': 76742,
#              'vendor': 'Arista'},
#   'interfaces': { 'Ethernet1': { 'description': 'link to leaf00.cmh',
#                                  'is_enabled': True,
#                                  'is_up': False,
#                                  'last_flapped': 1516010990.2331386,
#                                  'mac_address': '08:00:27:0C:31:79',
#                                  'speed': 0},
#                   'Ethernet2': { 'description': 'link to leaf01.cmh',
#                                  'is_enabled': True,
#                                  'is_up': True,
#                                  'last_flapped': 1515939602.295958,
#                                  'mac_address': '08:00:27:0C:31:79',
#                                  'speed': 0},
#                   'Management1': { 'description': '',
#                                    'is_enabled': True,
#                                    'is_up': True,
#                                    'last_flapped': 1515939616.808321,
#                                    'mac_address': '08:00:27:47:87:83',
#                                    'speed': 1000}}}
#
# * spine01.cmh ** changed : False ***********************************************
# ---- napalm_get ** changed : False  --------------------------------------------
# { 'facts': { 'fqdn': 'spine01.cmh.cmh.acme.com',
#              'hostname': 'spine01.cmh',
#              'interface_list': [ 'ge-0/0/0',
#                                  'gr-0/0/0',
#                                  'ip-0/0/0',
#                                  'lsq-0/0/0',
#                                  'lt-0/0/0',
#                                  'mt-0/0/0',
#                                  'sp-0/0/0',
#                                  'ge-0/0/1',
#                                  'ge-0/0/2',
#                                  '.local.',
#                                  'dsc',
#                                  'gre',
#                                  'ipip',
#                                  'irb',
#                                  'lo0',
#                                  'lsi',
#                                  'mtun',
#                                  'pimd',
#                                  'pime',
#                                  'pp0',
#                                  'ppd0',
#                                  'ppe0',
#                                  'st0',
#                                  'tap',
#                                  'vlan'],
#              'model': 'FIREFLY-PERIMETER',
#              'os_version': '12.1X47-D20.7',
#              'serial_number': '5efd44465d10',
#              'uptime': 76648,
#              'vendor': 'Juniper'},
#   'interfaces': { '.local.': { 'description': '',
#                                'is_enabled': True,
#                                'is_up': True,
#                                'last_flapped': -1.0,
#                                'mac_address': 'Unspecified',
#                                'speed': -1},
#                   'dsc': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'ge-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76597.0,
#                                 'mac_address': '08:00:27:AA:8C:76',
#                                 'speed': 1000},
#                   'ge-0/0/1': { 'description': 'link to leaf00.cmh',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76597.0,
#                                 'mac_address': '08:00:27:1A:7F:BF',
#                                 'speed': 1000},
#                   'ge-0/0/2': { 'description': 'link to leaf01.cmh',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76597.0,
#                                 'mac_address': '08:00:27:70:E5:81',
#                                 'speed': 1000},
#                   'gr-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': 'None',
#                                 'speed': 800},
#                   'gre': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'None',
#                            'speed': -1},
#                   'ip-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': 'None',
#                                 'speed': 800},
#                   'ipip': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'irb': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': '4C:96:14:8C:76:B0',
#                            'speed': -1},
#                   'lo0': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'lsi': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'lsq-0/0/0': { 'description': '',
#                                  'is_enabled': True,
#                                  'is_up': True,
#                                  'last_flapped': 76598.0,
#                                  'mac_address': 'None',
#                                  'speed': -1},
#                   'lt-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': '02:96:14:8C:76:B3',
#                                 'speed': 800},
#                   'mt-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': 'None',
#                                 'speed': 800},
#                   'mtun': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'pimd': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'pime': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'pp0': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'ppd0': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': 800},
#                   'ppe0': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': 800},
#                   'sp-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76598.0,
#                                 'mac_address': 'Unspecified',
#                                 'speed': 800},
#                   'st0': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'None',
#                            'speed': -1},
#                   'tap': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'vlan': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': False,
#                             'last_flapped': 76607.0,
#                             'mac_address': '00:00:00:00:00:00',
#                             'speed': 1000}}}
#
# * leaf00.cmh ** changed : False ************************************************
# ---- napalm_get ** changed : False  --------------------------------------------
# { 'facts': { 'fqdn': 'leaf00.cmh.cmh.acme.com',
#              'hostname': 'leaf00.cmh',
#              'interface_list': ['Ethernet1', 'Ethernet2', 'Management1'],
#              'model': 'vEOS',
#              'os_version': '4.17.5M-4414219.4175M',
#              'serial_number': '',
#              'uptime': 76556,
#              'vendor': 'Arista'},
#   'interfaces': { 'Ethernet1': { 'description': 'link to spine00.cmh',
#                                  'is_enabled': False,
#                                  'is_up': False,
#                                  'last_flapped': 1516010957.639385,
#                                  'mac_address': '08:00:27:0C:31:79',
#                                  'speed': 0},
#                   'Ethernet2': { 'description': 'link to spine01.cmh',
#                                  'is_enabled': True,
#                                  'is_up': True,
#                                  'last_flapped': 1515939788.3633773,
#                                  'mac_address': '08:00:27:0C:31:79',
#                                  'speed': 0},
#                   'Management1': { 'description': '',
#                                    'is_enabled': True,
#                                    'is_up': True,
#                                    'last_flapped': 1515939804.0736248,
#                                    'mac_address': '08:00:27:47:87:83',
#                                    'speed': 1000}}}
#
# * leaf01.cmh ** changed : False ************************************************
# ---- napalm_get ** changed : False  --------------------------------------------
# { 'facts': { 'fqdn': 'leaf01.cmh.cmh.acme.com',
#              'hostname': 'leaf01.cmh',
#              'interface_list': [ 'ge-0/0/0',
#                                  'gr-0/0/0',
#                                  'ip-0/0/0',
#                                  'lsq-0/0/0',
#                                  'lt-0/0/0',
#                                  'mt-0/0/0',
#                                  'sp-0/0/0',
#                                  'ge-0/0/1',
#                                  'ge-0/0/2',
#                                  '.local.',
#                                  'dsc',
#                                  'gre',
#                                  'ipip',
#                                  'irb',
#                                  'lo0',
#                                  'lsi',
#                                  'mtun',
#                                  'pimd',
#                                  'pime',
#                                  'pp0',
#                                  'ppd0',
#                                  'ppe0',
#                                  'st0',
#                                  'tap',
#                                  'vlan'],
#              'model': 'FIREFLY-PERIMETER',
#              'os_version': '12.1X47-D20.7',
#              'serial_number': '9d842799f666',
#              'uptime': 76460,
#              'vendor': 'Juniper'},
#   'interfaces': { '.local.': { 'description': '',
#                                'is_enabled': True,
#                                'is_up': True,
#                                'last_flapped': -1.0,
#                                'mac_address': 'Unspecified',
#                                'speed': -1},
#                   'dsc': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'ge-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76407.0,
#                                 'mac_address': '08:00:27:AA:8C:76',
#                                 'speed': 1000},
#                   'ge-0/0/1': { 'description': 'link to spine00.cmh',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76407.0,
#                                 'mac_address': '08:00:27:A0:42:60',
#                                 'speed': 1000},
#                   'ge-0/0/2': { 'description': 'link to spine01.cmh',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76407.0,
#                                 'mac_address': '08:00:27:00:6D:5A',
#                                 'speed': 1000},
#                   'gr-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': 'None',
#                                 'speed': 800},
#                   'gre': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'None',
#                            'speed': -1},
#                   'ip-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': 'None',
#                                 'speed': 800},
#                   'ipip': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'irb': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': '4C:96:14:8C:76:B0',
#                            'speed': -1},
#                   'lo0': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'lsi': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'lsq-0/0/0': { 'description': '',
#                                  'is_enabled': True,
#                                  'is_up': True,
#                                  'last_flapped': 76408.0,
#                                  'mac_address': 'None',
#                                  'speed': -1},
#                   'lt-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': '02:96:14:8C:76:B3',
#                                 'speed': 800},
#                   'mt-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': -1.0,
#                                 'mac_address': 'None',
#                                 'speed': 800},
#                   'mtun': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'pimd': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'pime': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': -1},
#                   'pp0': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'ppd0': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': 800},
#                   'ppe0': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': True,
#                             'last_flapped': -1.0,
#                             'mac_address': 'None',
#                             'speed': 800},
#                   'sp-0/0/0': { 'description': '',
#                                 'is_enabled': True,
#                                 'is_up': True,
#                                 'last_flapped': 76408.0,
#                                 'mac_address': 'Unspecified',
#                                 'speed': 800},
#                   'st0': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'None',
#                            'speed': -1},
#                   'tap': { 'description': '',
#                            'is_enabled': True,
#                            'is_up': True,
#                            'last_flapped': -1.0,
#                            'mac_address': 'Unspecified',
#                            'speed': -1},
#                   'vlan': { 'description': '',
#                             'is_enabled': True,
#                             'is_up': False,
#                             'last_flapped': 76417.0,
#                             'mac_address': '00:00:00:00:00:00',
#                             'speed': 1000}}}
