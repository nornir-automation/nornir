# %%
# ignore this cell, this is just a helper cell to provide the magic %highlight_file
# %run ../highlighter.py

# %% [markdown]
# # Configure
#
# This is a runbook to configure the network. To do so we are going to load first some data from the directory `../extra_data/` and then a bunch of templates to generate, based on that extra data, the configuration for the devices.
#
# ## Extra data
#
# Let's first look at the extra data we are going to use:

# %%
# %ls ../extra_data/*
# Out:
# ../extra_data/leaf00.cmh:
# l3.yaml
#
# ../extra_data/leaf01.cmh:
# l3.yaml
#
# ../extra_data/spine00.cmh:
# l3.yaml
#
# ../extra_data/spine01.cmh:
# l3.yaml

# %% [markdown]
# Now let's look at one of the files for reference:

# %%
% cat ../extra_data/leaf00.cmh/l3.yaml
# Out:
# ---
# interfaces:
#   Ethernet1:
#     connects_to: spine00.cmh
#     ipv4: 10.0.0.1/31
#     enabled: false
#   Ethernet2:
#     connects_to: spine01.cmh
#     ipv4: 10.0.1.1/31
#     enabled: true
#
# sessions:
#   - ipv4: 10.0.0.0
#     peer_as: 65000
#   - ipv4: 10.0.1.0
#     peer_as: 65000

# %% [markdown]
# ## Templates
#
# To configure the network we will transform the data we saw before into actual configurationusing jinja2 templates. The templates are:

# %%
# %ls ../templates/*
# Out:
# ../templates/eos:
# base.j2        interfaces.j2  leaf.j2        routing.j2     spine.j2
#
# ../templates/junos:
# base.j2        interfaces.j2  leaf.j2        routing.j2     spine.j2

# %% [markdown]
# As an example, let's look how the ``interfaces.j2`` template will consume the extra data we saw before to configure the interfaces:

# %%
# %cat ../templates/eos/interfaces.j2
# Out:
# {% for interface, data in l3.interfaces.items() %}
# interface {{ interface }}
#    no switchport
#    ip address {{ data.ipv4 }}
#    description link to {{ data.connects_to }}
#    {{ "no" if data.enabled else "" }} shutdown
# {% endfor %}

# %% [markdown]
# ## Code
#
# Now let's look at the code that will sticth everything together:

# %%
# %highlight_file configure.py
# Out:
# <style>
# .pygments .hll { background-color: #ffffcc }
# .pygments  { background: #f8f8f8; }
# .pygments .c { color: #408080; font-style: italic } /* Comment */
# .pygments .err { border: 1px solid #FF0000 } /* Error */
# .pygments .k { color: #008000; font-weight: bold } /* Keyword */
# .pygments .o { color: #666666 } /* Operator */
# .pygments .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .pygments .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .pygments .cp { color: #BC7A00 } /* Comment.Preproc */
# .pygments .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .pygments .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .pygments .cs { color: #408080; font-style: italic } /* Comment.Special */
# .pygments .gd { color: #A00000 } /* Generic.Deleted */
# .pygments .ge { font-style: italic } /* Generic.Emph */
# .pygments .gr { color: #FF0000 } /* Generic.Error */
# .pygments .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .pygments .gi { color: #00A000 } /* Generic.Inserted */
# .pygments .go { color: #888888 } /* Generic.Output */
# .pygments .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .pygments .gs { font-weight: bold } /* Generic.Strong */
# .pygments .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .pygments .gt { color: #0044DD } /* Generic.Traceback */
# .pygments .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .pygments .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .pygments .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .pygments .kp { color: #008000 } /* Keyword.Pseudo */
# .pygments .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .pygments .kt { color: #B00040 } /* Keyword.Type */
# .pygments .m { color: #666666 } /* Literal.Number */
# .pygments .s { color: #BA2121 } /* Literal.String */
# .pygments .na { color: #7D9029 } /* Name.Attribute */
# .pygments .nb { color: #008000 } /* Name.Builtin */
# .pygments .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .pygments .no { color: #880000 } /* Name.Constant */
# .pygments .nd { color: #AA22FF } /* Name.Decorator */
# .pygments .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .pygments .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .pygments .nf { color: #0000FF } /* Name.Function */
# .pygments .nl { color: #A0A000 } /* Name.Label */
# .pygments .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .pygments .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .pygments .nv { color: #19177C } /* Name.Variable */
# .pygments .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .pygments .w { color: #bbbbbb } /* Text.Whitespace */
# .pygments .mb { color: #666666 } /* Literal.Number.Bin */
# .pygments .mf { color: #666666 } /* Literal.Number.Float */
# .pygments .mh { color: #666666 } /* Literal.Number.Hex */
# .pygments .mi { color: #666666 } /* Literal.Number.Integer */
# .pygments .mo { color: #666666 } /* Literal.Number.Oct */
# .pygments .sa { color: #BA2121 } /* Literal.String.Affix */
# .pygments .sb { color: #BA2121 } /* Literal.String.Backtick */
# .pygments .sc { color: #BA2121 } /* Literal.String.Char */
# .pygments .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .pygments .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .pygments .s2 { color: #BA2121 } /* Literal.String.Double */
# .pygments .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .pygments .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .pygments .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .pygments .sx { color: #008000 } /* Literal.String.Other */
# .pygments .sr { color: #BB6688 } /* Literal.String.Regex */
# .pygments .s1 { color: #BA2121 } /* Literal.String.Single */
# .pygments .ss { color: #19177C } /* Literal.String.Symbol */
# .pygments .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .pygments .fm { color: #0000FF } /* Name.Function.Magic */
# .pygments .vc { color: #19177C } /* Name.Variable.Class */
# .pygments .vg { color: #19177C } /* Name.Variable.Global */
# .pygments .vi { color: #19177C } /* Name.Variable.Instance */
# .pygments .vm { color: #19177C } /* Name.Variable.Magic */
# .pygments .il { color: #666666 } /* Literal.Number.Integer.Long */
# </style>
# <div class="pygments"><pre><span></span><span class="lineno"> 1 </span><span class="ch">#!/usr/bin/env python</span>
# <span class="lineno"> 2 </span><span class="sd">&quot;&quot;&quot;</span>
# <span class="lineno"> 3 </span><span class="sd">Runbook to configure datacenter</span>
# <span class="lineno"> 4 </span><span class="sd">&quot;&quot;&quot;</span>
# <span class="lineno"> 5 </span><span class="kn">from</span> <span class="nn">brigade.easy</span> <span class="k">import</span> <span class="n">easy_brigade</span>
# <span class="lineno"> 6 </span><span class="kn">from</span> <span class="nn">brigade.plugins.functions.text</span> <span class="k">import</span> <span class="n">print_title</span>
# <span class="lineno"> 7 </span><span class="kn">from</span> <span class="nn">brigade.plugins.tasks</span> <span class="k">import</span> <span class="n">data</span><span class="p">,</span> <span class="n">networking</span><span class="p">,</span> <span class="n">text</span>
# <span class="lineno"> 8 </span>
# <span class="lineno"> 9 </span>
# <span class="lineno">10 </span><span class="k">def</span> <span class="nf">configure</span><span class="p">(</span><span class="n">task</span><span class="p">):</span>
# <span class="lineno">11 </span>    <span class="sd">&quot;&quot;&quot;</span>
# <span class="lineno">12 </span><span class="sd">    This function groups all the tasks needed to configure the</span>
# <span class="lineno">13 </span><span class="sd">    network:</span>
# <span class="lineno">14 </span>
# <span class="lineno">15 </span><span class="sd">        1. Loading extra data</span>
# <span class="lineno">16 </span><span class="sd">        2. Templates to build configuration</span>
# <span class="lineno">17 </span><span class="sd">        3. Deploy configuration on the device</span>
# <span class="lineno">18 </span><span class="sd">    &quot;&quot;&quot;</span>
# <span class="lineno">19 </span>    <span class="n">r</span> <span class="o">=</span> <span class="n">task</span><span class="o">.</span><span class="n">run</span><span class="p">(</span><span class="n">text</span><span class="o">.</span><span class="n">template_file</span><span class="p">,</span>
# <span class="lineno">20 </span>                 <span class="n">name</span><span class="o">=</span><span class="s2">&quot;Base Configuration&quot;</span><span class="p">,</span>
# <span class="lineno">21 </span>                 <span class="n">template</span><span class="o">=</span><span class="s2">&quot;base.j2&quot;</span><span class="p">,</span>
# <span class="lineno">22 </span>                 <span class="n">path</span><span class="o">=</span><span class="s2">&quot;../templates/</span><span class="si">{brigade_nos}</span><span class="s2">&quot;</span><span class="p">)</span>
# <span class="lineno">23 </span>    <span class="c1"># r.result holds the result of rendering the template</span>
# <span class="lineno">24 </span>    <span class="c1"># we store in the host itself so we can keep updating</span>
# <span class="lineno">25 </span>    <span class="c1"># it as we render other templates</span>
# <span class="lineno">26 </span>    <span class="n">task</span><span class="o">.</span><span class="n">host</span><span class="p">[</span><span class="s2">&quot;config&quot;</span><span class="p">]</span> <span class="o">=</span> <span class="n">r</span><span class="o">.</span><span class="n">result</span>
# <span class="lineno">27 </span>
# <span class="lineno">28 </span>    <span class="n">r</span> <span class="o">=</span> <span class="n">task</span><span class="o">.</span><span class="n">run</span><span class="p">(</span><span class="n">data</span><span class="o">.</span><span class="n">load_yaml</span><span class="p"

# %% [markdown]
# ## Demo
#
# Finally let's see everything in action:

# %%
# %run configure.py
# Out:
# **** Playbook to configure the network *****************************************
# * spine00.cmh ** changed : True ************************************************
# ---- Loading Configuration on the device ** changed : True  --------------------
# @@ -8,7 +8,8 @@
#  !
#  transceiver qsfp default-mode 4x10G
#  !
# -hostname localhost
# +hostname spine00.cmh
# +ip domain-name cmh.acme.com
#  !
#  spanning-tree mode mstp
#  !
# @@ -20,13 +21,28 @@
#  username vagrant privilege 15 role network-admin secret sha512 $6$kRQZJTqx69hOW5ag$Y6VX8Kk37TWEsriKdr6ixqvMuUSSbuFu2Eh/5SIet2TCeXP3bdlwikIAruPp6lHB5HdC.t6tPsZVctHMU7H590
#  !
#  interface Ethernet1
# +   description link to leaf00.cmh
# +   no switchport
# +   ip address 10.0.0.0/31
#  !
#  interface Ethernet2
# +   description link to leaf01.cmh
# +   no switchport
# +   ip address 10.0.0.2/31
#  !
#  interface Management1
#     ip address 10.0.2.15/24
#  !
# -no ip routing
# +ip routing
# +!
# +router bgp 65000
# +   neighbor 10.0.0.1 remote-as 65100
# +   neighbor 10.0.0.1 maximum-routes 12000
# +   neighbor 10.0.0.3 remote-as 65101
# +   neighbor 10.0.0.3 maximum-routes 12000
# +   address-family ipv4
# +      neighbor 10.0.0.1 activate
# +      neighbor 10.0.0.3 activate
#  !
#  management api http-commands
#     no shutdown
#
# * spine01.cmh ** changed : True ************************************************
# ---- Loading Configuration on the device ** changed : True  --------------------
# [edit system]
# -  host-name vsrx;
# +  host-name spine01.cmh;
# +  domain-name cmh.acme.com;
# [edit interfaces]
# +   ge-0/0/1 {
# +       description "link to leaf00.cmh";
# +       unit 0 {
# +           family inet {
# +               address 10.0.1.0/31;
# +           }
# +       }
# +   }
# +   ge-0/0/2 {
# +       description "link to leaf01.cmh";
# +       unit 0 {
# +           family inet {
# +               address 10.0.1.2/31;
# +           }
# +       }
# +   }
# [edit]
# +  routing-options {
# +      autonomous-system 65000;
# +  }
# +  protocols {
# +      bgp {
# +          import PERMIT_ALL;
# +          export PERMIT_ALL;
# +          group peers {
# +              neighbor 10.0.1.1 {
# +                  peer-as 65100;
# +              }
# +              neighbor 10.0.1.3 {
# +                  peer-as 65101;
# +              }
# +          }
# +      }
# +  }
# +  policy-options {
# +      policy-statement PERMIT_ALL {
# +          from protocol bgp;
# +          then accept;
# +      }
# +  }
#
# * leaf00.cmh ** changed : True *************************************************
# ---- Loading Configuration on the device ** changed : True  --------------------
# @@ -8,6 +8,9 @@
#  !
#  transceiver qsfp default-mode 4x10G
#  !
# +hostname leaf00.cmh
# +ip domain-name cmh.acme.com
# +!
#  spanning-tree mode mstp
#  !
#  aaa authorization exec default local
# @@ -17,14 +20,36 @@
#  username admin privilege 15 role network-admin secret sha512 $6$/K1M3ENrC/xALAOm$1vCB5TfaI8ih5GQRCwhRE7KGzmc.EGuQZ7dEuwhP7AJC0/A97u88miINH/7GtrBpRZ.Inn5JY9tuymMcmyyKc.
#  username vagrant privilege 15 role network-admin secret sha512 $6$9CGTCvCiiJK3lDMp$kU9ncPDBkw0w09.h9wIhQtMAkZ/1zD1ds/wlAZAtmSQf5ntNMjDgvmZpBcXWAPAETlk4.kA9niLTVmQwaLBV/.
#  !
# +vlan 100
# +   name frontend
# +!
# +vlan 200
# +   name backend
# +!
#  interface Ethernet1
# +   description link to spine00.cmh
# +   shutdown
# +   no switchport
# +   ip address 10.0.0.1/31
#  !
#  interface Ethernet2
# +   description link to spine01.cmh
# +   no switchport
# +   ip address 10.0.1.1/31
#  !
#  interface Management1
#     ip address 10.0.2.15/24
#  !
# -no ip routing
# +ip routing
# +!
# +router bgp 65100
# +   neighbor 10.0.0.0 remote-as 65000
# +   neighbor 10.0.0.0 maximum-routes 12000
# +   neighbor 10.0.1.0 remote-as 65000
# +   neighbor 10.0.1.0 maximum-routes 12000
# +   address-family ipv4
# +      neighbor 10.0.0.0 activate
# +      neighbor 10.0.1.0 activate
#  !
#  management api http-commands
#     no shutdown
#
# * leaf01.cmh ** changed : True *************************************************
# ---- Loading Configuration on the device ** changed : True  --------------------
# [edit system]
# -  host-name vsrx;
# +  host-name leaf01.cmh;
# +  domain-name cmh.acme.com;
# [edit interfaces]
# +   ge-0/0/1 {
# +       description "link to spine00.cmh";
# +       unit 0 {
# +           family inet {
# +               address 10.0.0.3/31;
# +           }
# +       }
# +   }
# +   ge-0/0/2 {
# +       description "link to spine01.cmh";
# +       unit 0 {
# +           family inet {
# +               address 10.0.1.3/31;
# +           }
# +       }
# +   }
# [edit]
# +  routing-options {
# +      autonomous-system 65101;
# +  }
# +  protocols {
# +      bgp {
# +          import PERMIT_ALL;
# +          export PERMIT_ALL;
# +          group peers {
# +              neighbor 10.0.0.2 {
# +                  peer-as 65000;
# +              }
# +              neighbor 10.0.1.2 {
# +                  peer-as 65000;
# +              }
# +          }
# +      }
# +  }
# +  policy-options {
# +      policy-statement PERMIT_ALL {
# +          from protocol bgp;
# +          then accept;
# +      }
# +  }
# +  vlans {
# +      backend {
# +          vlan-id 200;
# +      }
# +      frontend {
# +          vlan-id 100;
# +      }
# +  }

# %%
# %run configure.py
# Out:
# **** Playbook to configure the network *****************************************
# * spine00.cmh ** changed : False ***********************************************
# ---- Loading Configuration on the device ** changed : False  -------------------
#
# * spine01.cmh ** changed : False ***********************************************
# ---- Loading Configuration on the device ** changed : False  -------------------
#
# * leaf00.cmh ** changed : False ************************************************
# ---- Loading Configuration on the device ** changed : False  -------------------
#
# * leaf01.cmh ** changed : False ************************************************
# ---- Loading Configuration on the device ** changed : False  -------------------

# %% [markdown]
# The tool also detects unwanted changes and corrects them. For instance, let's change the hostname manually:
#
#     spine00.cmh((config)#hostname localhost
#     localhost(config)#
#
# And run the runbook again:

# %%
# %run configure.py
# Out:
# **** Playbook to configure the network *****************************************
# * spine00.cmh ** changed : True ************************************************
# ---- Loading Configuration on the device ** changed : True  --------------------
# @@ -8,7 +8,7 @@
#  !
#  transceiver qsfp default-mode 4x10G
#  !
# -hostname localhost
# +hostname spine00.cmh
#  ip domain-name cmh.acme.com
#  !
#  spanning-tree mode mstp
#
# * spine01.cmh ** changed : False ***********************************************
# ---- Loading Configuration on the device ** changed : False  -------------------
#
# * leaf00.cmh ** changed : False ************************************************
# ---- Loading Configuration on the device ** changed : False  -------------------
#
# * leaf01.cmh ** changed : False ************************************************
# ---- Loading Configuration on the device ** changed : False  -------------------
